# %%
import sys

# !{sys.executable} -m pip install opencv-python numpy matplotlib ultralytics
# Out:
# Requirement already satisfied: opencv-python in c:\users\sathya\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy in c:\users\sathya\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\sathya\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: ultralytics in c:\users\sathya\anaconda3\lib\site-packages (8.4.154)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sathya\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (3.1.1)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (2.14.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (0.29.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (1.44.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: ultralytics-platform>=0.1.45 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics) (0.1.46)
# Requirement already satisfied: polars-runtime-32==1.44.2 in c:\users\sathya\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.44.2)
# Requirement already satisfied: six>=1.5 in c:\users\sathya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sathya\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sathya\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sathya\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sathya\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sathya\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sathya\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.28 in c:\users\sathya\anaconda3\lib\site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in c:\users\sathya\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sathya\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sathya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sathya\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sathya\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
# PROGRAM4: Lane Detection – OpenCV Canny + ROI + Hough Transform

import cv2
import numpy as np
import matplotlib.pyplot as plt


image = cv2.imread("road.jpg")

if image is None:
    raise FileNotFoundError("road.jpg not found")


output = image.copy()

gray = cv2.cvtColor(
    image,
    cv2.COLOR_BGR2GRAY
)

blur = cv2.GaussianBlur(
    gray,
    (5, 5),
    0
)

edges = cv2.Canny(
    blur,
    50,
    150
)

h, w = edges.shape

mask = np.zeros_like(edges)


polygon = np.array([[
    (0, h),
    (w, h),
    (int(0.58 * w), int(0.58 * h)),
    (int(0.42 * w), int(0.58 * h))
]], dtype=np.int32)


cv2.fillPoly(
    mask,
    polygon,
    255
)

roi_edges = cv2.bitwise_and(
    edges,
    mask
)


# HOUGH TRANSFORM

lines = cv2.HoughLinesP(
    roi_edges,
    rho=1,
    theta=np.pi / 180,
    threshold=30,
    minLineLength=30,
    maxLineGap=100
)


left_lines = []
right_lines = []


if lines is not None:

    # Makes line format consistently:
    # [x1, y1, x2, y2]

    lines = lines.reshape(-1, 4)

    for x1, y1, x2, y2 in lines:

        # Avoid division by zero
        if x2 == x1:
            continue

        # Calculate slope
        slope = (y2 - y1) / (x2 - x1)

        # Negative slope = left lane
        if -1.5 < slope < -0.4:
            left_lines.append(
                (x1, y1, x2, y2)
            )

        # Positive slope = right lane
        elif 0.4 < slope < 1.5:
            right_lines.append(
                (x1, y1, x2, y2)
            )


def average_line(lines, y_bottom, y_top):

    if len(lines) == 0:
        return None

    xs = []
    ys = []

    for x1, y1, x2, y2 in lines:

        xs.extend([x1, x2])
        ys.extend([y1, y2])

    # Fit line: y = slope*x + intercept

    slope, intercept = np.polyfit(
        xs,
        ys,
        1
    )

    if abs(slope) < 1e-6:
        return None

    x_bottom = int(
        (y_bottom - intercept) / slope
    )

    x_top = int(
        (y_top - intercept) / slope
    )

    return (
        x_bottom,
        y_bottom,
        x_top,
        y_top
    )


y_bottom = h - 1

y_top = int(
    0.60 * h
)


left_lane = average_line(
    left_lines,
    y_bottom,
    y_top
)

right_lane = average_line(
    right_lines,
    y_bottom,
    y_top
)


if left_lane is not None:

    x1, y1, x2, y2 = left_lane

    cv2.line(
        output,
        (x1, y1),
        (x2, y2),
        (0, 255, 0),
        8
    )


if right_lane is not None:

    x1, y1, x2, y2 = right_lane

    cv2.line(
        output,
        (x1, y1),
        (x2, y2),
        (0, 255, 0),
        8
    )


output_rgb = cv2.cvtColor(
    output,
    cv2.COLOR_BGR2RGB
)


plt.figure(
    figsize=(14, 8)
)

plt.imshow(output_rgb)

plt.title(
    "Lane Detection Output"
)

plt.axis("off")

plt.show()
